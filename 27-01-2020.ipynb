# %%
Inserting a New node at the end of the Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	// Insert Node at the End of List
	//Allocate the memory for new node malloc
	struct Node *nn = (struct Node *) malloc(sizeof(struct Node));
	//Accept the Value for Data
	printf("\n Enter the value ");
	scanf("%d",&nn->Data);
	//New Node Next memory has to Point to NULL
	nn->Next = NULL;
	//If there is only single node
	if(S==NULL){
		S = L = nn;
	}
	else{
		L->Next = nn;
		L = nn;
	}
	printf("\n Node is added at the end of List");
	getch();
}
void deleteNode(){
	printf("\n Delete Node");
	getch();
}
void displayNodes(){
	
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
		}
	}
	getch();
}

# %%
Inserting a New Node at Starting of Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter a value ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		nn->Next = S;
		S = nn;
	}
	printf("\n New Node is inserted at Start of List");
	getch();
}
void deleteNode(){
	printf("\n Delete Node");
	getch();
}
void displayNodes(){
	
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
		}
	}
	getch();
}

# %%
Inserting a New Node in the Middle of Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		if(nn->Data < S->Data){
			nn->Next = S;
			S = nn;
		}
		else if(nn->Data > L->Data){
			L->Next = nn;
			L = nn;
		}
		else{
			for(C=S;C->Data<nn->Data;P=C,C=C->Next);
			nn->Next = C;
			P->Next = nn;
		}
	}
	getch();
}
void deleteNode(){
	printf("\n Delete Node");
	getch();
}
void displayNodes(){
	
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
		}
	}
	getch();
}

# %%
Inserting a New Node at Random Position and Finding the Len of Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position");
		scanf("%d",&pos);
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;	
		}		
	}
	getch();
}
void deleteNode(){
	printf("\n Delete Node");
	getch();
}
void displayNodes(){
	int x;
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
			x++;
		}
	}
	printf("\n%d are Present in the List",x);
	getch();
}

# %%
Input : Data
Ouput : Target Data Position in the Linked List

Example : 12 13 19 11 18 20
Input : 19
Output : 3

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();
void searchNode();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Search - ");
		printf("\n ----5. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4 : searchNode();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position");
		scanf("%d",&pos);
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;	
		}		
	}
	getch();
}
void deleteNode(){
	printf("\n Delete Node");
	getch();
}
void displayNodes(){
	int x;
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
			x++;
		}
	}
	printf("\n%d are Present in the List",x);
	getch();
}
void searchNode(){
	int k,i=0,cnt=0;
	printf("\n Enter the key : ");
	scanf("%d",&k);
	for(C=S;C!=NULL;C=C->Next,i++){
		if(C->Data == k){
			printf("%d ",(i+1));
			cnt++;
		}
	}
	if(cnt==0){
		printf("\n Key is not present in the Linked List");
	}
	getch();
}

# %%
Delete a Node in Linked List - Start

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();
void searchNode();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Search - ");
		printf("\n ----5. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4 : searchNode();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position");
		scanf("%d",&pos);
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;	
		}		
	}
	getch();
}
void deleteNode(){
	if(S==NULL){
		printf("\n Linked List is Empty ");
	}
	else{
		//Check whether having single node or more
		//Single node
		if(S->Next == NULL){
			S = L = NULL;
			printf("\n Node is Deleted...");
		}
		else{
			C = S;
			S = S->Next;
			C->Next = NULL;
			C = NULL;
			printf("\n Node is Deleted from Start ...");
		}
	}
	getch();
}
void displayNodes(){
	int x;
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
			x++;
		}
	}
	printf("\n%d are Present in the List",x);
	getch();
}
void searchNode(){
	int k,i=0,cnt=0;
	printf("\n Enter the key : ");
	scanf("%d",&k);
	for(C=S;C!=NULL;C=C->Next,i++){
		if(C->Data == k){
			printf("%d ",(i+1));
			cnt++;
		}
	}
	if(cnt==0){
		printf("\n Key is not present in the Linked List");
	}
	getch();
}

# %%
Delete Node in Linked List - End

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();
void searchNode();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Search - ");
		printf("\n ----5. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4 : searchNode();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position");
		scanf("%d",&pos);
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;	
		}		
	}
	getch();
}
void deleteNode(){
	if(S==NULL){
		printf("\n Linked List Empty ");
	}
	else{
		if(S->Next==NULL){
			S = L = NULL;
			printf("\n Node is deleted...");
		}
		else
		{
			for(C=S;C!=L;P=C,C=C->Next);
			L = P;
			P->Next = NULL;
			P = NULL;
			C = NULL;
			printf("\n Node is deleted...");
		}
	}
	getch();
}
void displayNodes(){
	int x;
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
			x++;
		}
	}
	printf("\n%d are Present in the List",x);
	getch();
}
void searchNode(){
	int k,i=0,cnt=0;
	printf("\n Enter the key : ");
	scanf("%d",&k);
	for(C=S;C!=NULL;C=C->Next,i++){
		if(C->Data == k){
			printf("%d ",(i+1));
			cnt++;
		}
	}
	if(cnt==0){
		printf("\n Key is not present in the Linked List");
	}
	getch();
}

# %%
Delte the Node from Start, End and Middle
# Out:
#   File "<ipython-input-1-ac7b48cac737>", line 1
#     Delte the Node from Start, End and Middle
#             ^
# SyntaxError: invalid syntax

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();
void searchNode();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Search - ");
		printf("\n ----5. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4 : searchNode();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position");
		scanf("%d",&pos);
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;	
		}		
	}
	getch();
}
void deleteNode(){
	int n;
	printf("\n Enter a Value : ");
	scanf("%d",&n);
	if(S->Next==NULL && n==S->Data){
		S = L = NULL;
		printf("\n Node is deleted...");
	}
	else if(n==S->Data){
		C = S;
		S = S->Next;
		C->Next = NULL;
		C = NULL;
		printf("\n Node is deleted...");
	}
	else if(n==L->Data){
		for(C=S;C!=L;P=C,C=C->Next);
		L = P;
		P->Next = NULL;
		C = NULL;
		P = NULL;
		printf("\n Node is deleted...");
	}
	else{
	for(C=S;C!=NULL && C->Data!=n;P=C,C=C->Next);
		if(C==NULL){
			printf("\n Node is not found");
		}
		else{
			P->Next = C->Next;
			C->Next = NULL;
			C = NULL;
			printf("\n Node is deleted...");
		}
	}
	getch();
}
void displayNodes(){
	int x;
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
			x++;
		}
	}
	printf("\n%d are Present in the List",x);
	getch();
}
void searchNode(){
	int k,i=0,cnt=0;
	printf("\n Enter the key : ");
	scanf("%d",&k);
	for(C=S;C!=NULL;C=C->Next,i++){
		if(C->Data == k){
			printf("%d ",(i+1));
			cnt++;
		}
	}
	if(cnt==0){
		printf("\n Key is not present in the Linked List");
	}
	getch();
}

# %%
Linked List : 
    11 12 14 15 15 15 18
Input : 15
Output : 3

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;
// S - Start L - Last C - Current P - Previous

void insertNode();
void deleteNode();
void displayNodes();
void searchNode();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");
		printf("\n --------------- ");
		printf("\n ----1. Insert-- ");
		printf("\n ----2. Remove-- ");
		printf("\n ----3. Display- ");
		printf("\n ----4. Search - ");
		printf("\n ----5. Exit   - ");
		printf("\n Enter Your Choice ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();				
			break;
			case 3: displayNodes();
			break;
			case 4 : searchNode();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Value : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position");
		scanf("%d",&pos);
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;	
		}		
	}
	getch();
}
void deleteNode(){
	int n;
	printf("\n Enter a Value : ");
	scanf("%d",&n);
	if(S->Next==NULL && n==S->Data){
		S = L = NULL;
		printf("\n Node is deleted...");
	}
	else if(n==S->Data){
		C = S;
		S = S->Next;
		C->Next = NULL;
		C = NULL;
		printf("\n Node is deleted...");
	}
	else if(n==L->Data){
		for(C=S;C!=L;P=C,C=C->Next);
		L = P;
		P->Next = NULL;
		C = NULL;
		P = NULL;
		printf("\n Node is deleted...");
	}
	else{
	for(C=S;C!=NULL && C->Data!=n;P=C,C=C->Next);
		if(C==NULL){
			printf("\n Node is not found");
		}
		else{
			P->Next = C->Next;
			C->Next = NULL;
			C = NULL;
			printf("\n Node is deleted...");
		}
	}
	getch();
}
void displayNodes(){
	int x;
	if(S==NULL){
		printf("\n List is Empty...");
	}
	else{
		printf("\n ------------------ ");
		printf("\n --Linked List --- \n");
		for(C=S;C!=NULL;C=C->Next){
			printf("%d ",C->Data);
			x++;
		}
	}
	printf("\n%d are Present in the List",x);
	getch();
}
void searchNode(){
	int k,cnt=0;
	printf("\n Enter the key : ");
	scanf("%d",&k);
	for(C=S;C!=NULL;C=C->Next){
		if(C->Data == k){
			cnt++;
		}
	}
	printf("%d ",cnt);
	getch();
}
